# %% [markdown]
# Kết nối Driver

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Dataset

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="m92WYB4ch6PGGS3hp2A1")
project = rf.workspace("bach-khoa-da-nang-8bvyc").project("charactes_all")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to charactes_all-2 in yolov8:: 100%|██████████| 9288/9288 [00:03<00:00, 2379.42it/s]

# %% [markdown]
# # 2. Import thư viện YOLOv8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.0/654.0 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 395, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %% [markdown]
# # 3. Training Model

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 188MB/s]
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 4. Training next

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/test/detect/train/weights/best.pt data={dataset.location}/data.yaml epochs=2 imgsz=640
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 5. Validating

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/test/detect_train/train/weights/best.pt data=/content/charactes_all-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25857709 parameters, 0 gradients, 78.8 GFLOPs
# val: Scanning /content/charactes_all-2/valid/labels.cache... 860 images, 0 backgrounds, 0 corrupt: 100% 860/860 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/charactes_all-2/valid/images/ndata148_jpg.rf.96860871da2e656d3c76b213d0203203.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 54/54 [00:29<00:00,  1.84it/s]
#                    all        860       6943      0.941      0.966      0.972      0.763
#                      0        860        591      0.993      0.989      0.992      0.817
#                      1        860        847      0.986      0.993       0.99      0.694
#                      2        860        577      0.987      0.998      0.995      0.811
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/test/detect_retrain/train/weights/best.pt data=/content/charactes_all-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25857709 parameters, 0 gradients, 78.8 GFLOPs
# val: Scanning /content/charactes_all-2/valid/labels.cache... 860 images, 0 backgrounds, 0 corrupt: 100% 860/860 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/charactes_all-2/valid/images/ndata148_jpg.rf.96860871da2e656d3c76b213d0203203.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 54/54 [00:29<00:00,  1.82it/s]
#                    all        860       6943      0.934      0.974      0.956      0.754
#                      0        860        591      0.987      0.992      0.992       0.82
#                      1        860        847      0.981      0.994      0.988      0.691
#                      2        860        577      0.989      0.998      0.994      0.812
# ...

# %% [markdown]
# # 6. Predict

# %%
# Upload anh truc tiep
from google.colab import files

upload = files.upload()
filename = next(iter(upload))

print(f"Da tai len file : {filename}")
# Out:
#      <input type="file" id="files-38d84145-af96-408a-a758-ef15146769e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38d84145-af96-408a-a758-ef15146769e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Predict with CLI
# !yolo task=detect mode=predict model=/content/drive/MyDrive/test/detect_retrain/train/weights/best.pt source='/content/validate.jpg'
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25857709 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/1 /content/validate.jpg: 384x640 2 3s, 1 b, 1 d, 1 s, 110.4ms
# Speed: 2.1ms preprocess, 110.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Predict with CLI
# !yolo task=detect mode=predict model=/content/drive/MyDrive/test/detect_train/train/weights/best.pt source='/content/validate.jpg'
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25857709 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/1 /content/validate.jpg: 384x640 1 2, 3 3s, 2 8s, 2 9s, 1 b, 1 e, 1 k, 109.3ms
# Speed: 2.1ms preprocess, 109.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
